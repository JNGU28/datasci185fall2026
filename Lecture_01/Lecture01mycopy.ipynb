# %%
print("Hello World")
print(2+4)
# Out:
# Hello World
# 6

# %%
print(2**3) #Comment
print(35//8)
print(35%8)
# Out:
# 8
# 4
# 3

# %%
#Log doesnt work, import package to get libraries to use certain functions
#Use import math
import math
print(math.log2(8))
# Out:
# 3.0

# %%
import statistics
print(statistics.mean([1,2,3,43,23,34]))
#Libraries differ by packages and enviroment. We installed pyhton on anaconda. What does that mean?
# Out:
# 17.666666666666668

# %%
#give statistics an alias
import statistics as stats
print(stats.mean([1,2,3,4,2]))
# Out:
# 2.4

# %%
import matplotlib.pyplot as plt
import pandas as pd
# how does this all work, how does this connect to anaconda?
#Jupyter's compiler is weird, its based off what the user clicks first, this is in segments not a giant notebook

# %%
carfeatures = pd.read_csv('data/features.csv')

# %% [markdown]
# ### Hello World

# %%
table = pd.crosstab(index = carfeatures['cylinders'],columns = "count")
display(table)

##Review syntax
# Out:
# col_0      count
# cylinders
# 3              4
# 4            204
# 5              3
# 6             84
# 8            103

# %%
help(pd.crosstab)
# Out:
# Help on function crosstab in module pandas:
#
# crosstab(
#     index,
#     columns,
#     values=None,
#     rownames=None,
#     colnames=None,
#     aggfunc=None,
#     margins: bool = False,
#     margins_name: Hashable = 'All',
#     dropna: bool = True,
#     normalize: bool | Literal[0, 1, 'all', 'index', 'columns'] = False
# ) -> DataFrame
#     Compute a simple cross tabulation of two (or more) factors.
#
#     By default, computes a frequency table of the factors unless an
#     array of values and an aggregation function are passed.
#
#     Parameters
#     ----------
#     index : array-like, Series, or list of arrays/Series
#         Values to group by in the rows.
#     columns : array-like, Series, or list of arrays/Series
#         Values to group by in the columns.
#     values : array-like, optional
#         Array of values to aggregate according to the factors.
#         Requires `aggfunc` be specified.
#     rownames : sequence, default None
# ...

# %%
carfeatures.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.427136  2970.424623     15.568090
# std      7.815984    1.701004    104.268683   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000

# %%
round(carfeatures.describe(),2)
# Out:
#           mpg  cylinders  displacement   weight  acceleration
# count  398.00     398.00        398.00   398.00        398.00
# mean    23.51       5.45        193.43  2970.42         15.57
# std      7.82       1.70        104.27   846.84          2.76
# min      9.00       3.00         68.00  1613.00          8.00
# 25%     17.50       4.00        104.25  2223.75         13.82
# 50%     23.00       4.00        148.50  2803.50         15.50
# 75%     29.00       8.00        262.00  3608.00         17.18
# max     46.60       8.00        455.00  5140.00         24.80

# %%
help(carfeatures.describe) # q1

carfeatures.describe(percentiles = [.33, .66])
# Out:
# Help on method describe in module pandas.core.generic:
#
# describe(percentiles=None, include=None, exclude=None) -> Self method of pandas.DataFrame instance
#     Generate descriptive statistics.
#
#     Descriptive statistics include those that summarize the central
#     tendency, dispersion and shape of a
#     dataset's distribution, excluding ``NaN`` values.
#
#     Analyzes both numeric and object series, as well
#     as ``DataFrame`` column sets of mixed data types. The output
#     will vary depending on what is provided. Refer to the notes
#     below for more detail.
#
#     Parameters
#     ----------
#     percentiles : list-like of numbers, optional
#         The percentiles to include in the output. All should
#         fall between 0 and 1. The default, ``None``, will automatically
#         return the 25th, 50th, and 75th percentiles.
#     include : 'all', list-like of dtypes or None (default), optional
# ...

# %%
#read then infer from help
#review lecture 1 and fill out all the notes

# for a 2 graph in one
plt.scatter(x = carfeatures['acceleration'], y = carfeatures['mpg'])


#important

plt.scatter(x = carfeatures['weight'], y = carfeatures['mpg'])
plt.xlabel("Acceleration")
plt.ylabel("Miles per gallon")
plt.title("Weight vs acceleration relative to mpg")
plt.show()







#
