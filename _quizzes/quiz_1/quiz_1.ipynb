# %% [markdown]
# # <span style="color:red"> DATASCI 185 - Quiz #1 </span>

# %% [markdown]
# <font size = "4" >
# This quiz is open book
#
# <br>
#
# - You <span style="color:red"> CAN </span> use all material from the course repo
#
# - You should <span style="color:red"> NOT </span> use other resources outside the course repo.
#
# - You should <span style="color:red"> NOT </span> collaborate with other students
#
# <!-- - Use of LLMs or any AI tools is <span style="color:red"> NOT ALLOWED </span> -->
#
# - AI assistance is <span style="color:red"> NOT </span> permitted for this assignment.
#
# - To get full credit, the code should work as intended. But try to attempt every problem - you can still receive partial credit.
#
# <br>
#
# Print the following string:
#
# "I will abide by Emory's code of conduct"

# %%
print("I will abide by Emory's code of conduct")

# %% [markdown]
# ______________________
#
# <font size = "4">
#
# **Question (A)** Read in data, generate descriptive statistics, create a scatter plot
#
# <font size = "3">
#
# - Using `pandas`, read in the file "StudentPerformanceFactors.csv" from the "quiz_data" folder and assign it to a variable named `df`.
#
# - Create a new variable by typing `cols = df.columns`. This corresponds to the column headings of the dataset.
#
# - Determine what **type** (a.k.a class) of object the variable `cols` is, and print it to the screen.

# %%
# your code here

import pandas as pd

df = pd.read_csv("quiz_data/StudentPerformanceFactors.csv")

cols = df.columns
print(type(cols)) ##Check syntax again.
# Out:
# <class 'pandas.Index'>

# %% [markdown]
# <font size = "3">
#
# You should see a type we haven't dealt with explicitly yet. Nevertheless, we can access the individual elements of "cols" in exactly the same way as for lists or arrays.
#
# - Using the `.describe` method, generate descriptive statistics for the column "Previous_Scores" and print it to the screen.
#
# - You should **not** explicitly type any part of the string "Previous_Scores", and you **should** use the variable `cols` you created above.

# %%
# your code here

##use describe, for Previous_scores in col. Seems to be third index in Data wrangler.
print(cols[3])
previousscores = cols[3]
df[cols[3]].describe()
# Out:
# Previous_Scores
# count    6607.000000
# mean       75.070531
# std        14.399784
# min        50.000000
# 25%        63.000000
# 50%        75.000000
# 75%        88.000000
# max       100.000000
# Name: Previous_Scores, dtype: float64

# %% [markdown]
# <font size = "3">
#
# - Generate a scatter plot of "Attendance" vs. "Exam_Score" for the dataset. ("Attendance" should be the x-axis variable.)
#
# - You should **not** explicitly type any part of the strings "Attendance" or "Exam_Score", and you **should** use the variable `cols` you created above.
#
# - Add labels to both the x and y axes, and add a title to your figure.
#
# - Use `plt.show()` to ensure no extraneous output is printed to the screen.

# %%
# your code here
import matplotlib.pyplot as plt
#scatter plot
plt.scatter(x = df[cols[1]], y = df[cols[6]])
#pandas_df = pd.read_csv("data/student_data.csv")
#not use any strings now
print(cols[1])
plt.xlabel([cols[1]])
plt.ylabel(cols[6])
plt.title(str(cols[1]) + " VS " + cols[6])
plt.show()
#scatter plot looks
# Out:
# Attendance

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (B)** String concatenation and list indexing
#
# <font size = "3">
#
# The goal of this exercise is to define a variable `message` that contains the string:
#
# <div align="center">"Peter's favorite song: 'More Than This' by Roxy Music" </div>
#
#
# - Change the definition of the variable `message` in the code cell below to coincide with the string mentioned above.
#
# - You should **only** change the line where `message` is defined. You shouldn't create any additional variables.
#
# - You should **not** type any strings explicitly (no using any double or single quotes).
#
# - Remember that `...` (an ellipsis) is just a placeholder for missing or uncompleted code. You should delete the ellipsis from the line of code.

# %%
lst = [" Music", "Peter's favorite song", ": ", "by ",
    "'More Than This'", " ", "Roxy"]

# change the definition of "message" below. ONLY change this line.
message = lst[1] + lst[2] + lst[4] + lst[5] + lst[3] + lst[6] + lst [0]


print(message)
# Out:
# Peter's favorite song: 'More Than This' by Roxy Music

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (C)** Nested lists and negative indexing
#
# <font size = "3">
#
# The code below generates a random list of lists. Write code that stores the **second to last** element of the **last** list in the variable `answer` regardless of what lists are generated. (You may want to run the cell multiple times to check your work)
#
# **NOTE**: you do NOT need to understand the Numpy commands used to generate the list. `random_list` is an ordinary python list and not a Numpy array.
#
# Examples:
#
# - If `random_list` is `[[6, 7, 7], [3, 6, 6], [7, 4, 2]]` then `answer` should be `4`.
#
# - If `random_list` is `[[1, 3, 3, 8], [3, 6, 9, 2]]` then `answer` should be `9`

# %%
import numpy as np

number_of_lists = np.random.randint(2, 6)
length_of_lists = np.random.randint(3, 5)
random_matrix = np.random.randint(1, 10, size=(number_of_lists, length_of_lists))

random_list = random_matrix.tolist()
print(random_list)


# change the definition of answer below
answer = ...
Lastarray = random_list[-1]
#nest it
print(Lastarray[-2])
answer = Lastarray[-2]
print(answer)
# Out:
# [[1, 1, 9], [4, 4, 3], [5, 2, 9], [8, 7, 8], [7, 3, 3]]
# 3
# 3

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (D)** Duplicating lists
#
# <font size = "3">
#
# A building has three lamps, and the code below is meant to record which lamps are on or off after each change, so we can look back at the history later.
#
# The intended output is:
# `[['on', 'off', 'off'], ['on', 'on', 'off'], ['off', 'on', 'off']]`
#
# but that is not what is printed.

# %%
lamps = ["off", "off", "off"]
history = []

history.append(lamps)

lamps[0] = "on"
history.append(lamps)

lamps[1] = "on"
history.append(lamps)

lamps[0] = "off"
history.append(lamps)

# 0 is off, 1 is on, 3 is left out. This is an overwrite issue
#simplest way is just to define new lamp variables.

print(history)
# Out:
# [['off', 'on', 'off'], ['off', 'on', 'off'], ['off', 'on', 'off'], ['off', 'on', 'off']]

# %% [markdown]
# <font size = "3">
#
# Provide your fixed code in the cell below

# %%
# fixed version of the code in previous cell
lamps = ["off", "off", "off"]
history = []

lamps1 = lamps.copy() 
lamps1[0] ='on'
history.append(lamps1)

lamps2 = lamps.copy()
lamps2[1] = 'on'
lamps2[0] = 'on'
history.append(lamps2)

lamps3 = lamps.copy() #duplicate list
lamps3[1] = 'on'
history.append(lamps3)


# 0 is off, 1 is on, 3 is left out. This is an overwrite issue
#simplest way is just to define new lamp variables.

print(history)
# Out:
# [['on', 'off', 'off'], ['on', 'on', 'off'], ['off', 'on', 'off']]

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (E)** Floating point equality
#
# <font size = "3">
#
# The next code cell defines three variables (`x`, `y`, and `z`) and then compares the result of a mathematical operation that in theory, should be equal to `y`. But when the cell is run, it prints out a message saying they are not the same.
#
# How would you choose a different comparison operation between `x`, `y`, and `z` so that Python prints `True` instead?
#
# **Note:** Feel free to define a new variable `t = x-z` if you would like.

# %%
x = 1
y = 0.1
z = 0.9
#x-z = 0.1 in human. But the difference could be very small,compare to very small number.
t = x-z 

print("x - z and y are equal:", (x-z) == y)

#compare t - y, should be 0 is equal, but problem is the acutal floating point is very small.
    
# Your code here
if (abs((t-y)) < 1e-13):
    print("x - z and y are equal.")
else:
    print("not equal")
#should print true
# Out:
# x - z and y are equal: False
# x - z and y are equal.

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (F)** Boolean operations
#
# <font size = "3">
#
# You are trying to schedule a time for a job interview. The following code cell reads in a text file and converts it to a Python list. The list contains dates in December, January, and February where the hiring manager is **not** available.
#
# Use the string variable `proposed_date`, the list variable `unavailable` and one or more Boolean operations to test whether an interview can be scheduled for January 13th. Your answer should replace the definition of the variable `bool_statement`.  The value of `bool_statement` should be `True` if Jan. 13th is available, and `False` otherwise.

# %%
# This code creates a list of strings:

with open("quiz_data/dates.txt") as f:
    unavailable = [line.strip() for line in f]

print(unavailable, '\n')

proposed_date = 'Jan. 13'
#proposed_date = 'Dec. 2'

print(f"An interview can be scheduled for {proposed_date}:")



# your code here
if proposed_date in unavailable:
    boolstatement = False
else:
    bool_statement = True

print(bool_statement)
# Out:
# ['Dec. 2', 'Jan. 17', 'Feb. 5', 'Dec. 11', 'Jan. 24', 'Feb. 3', 'Dec. 28', 'Jan. 8', 'Feb. 14', 'Dec. 6', 'Jan. 31', 'Feb. 22', 'Dec. 19', 'Jan. 12', 'Feb. 9', 'Dec. 25', 'Jan. 4', 'Feb. 27', 'Dec. 15', 'Jan. 20', 'Feb. 1', 'Dec. 30', 'Jan. 27', 'Feb. 18', 'Dec. 8', 'Jan. 10', 'Feb. 25', 'Dec. 22', 'Jan. 6', 'Feb. 12', 'Dec. 4', 'Jan. 29', 'Feb. 7', 'Dec. 17', 'Jan. 14', 'Feb. 20', 'Dec. 13', 'Jan. 2', 'Feb. 16', 'Dec. 27']
#
# An interview can be scheduled for Dec. 2:
# True
